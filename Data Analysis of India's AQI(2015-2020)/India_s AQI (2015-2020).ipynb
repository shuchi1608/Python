# %% [markdown]
# # INDIA'S AQI(2015-2020)

# %% [markdown]
# ## Introduction

# %% [markdown]
# An Air Quality Index (AQI) is a number used by government agencies to measure the air pollution levels and communicate it to the population. As the AQI increases, it means that a large percentage of the population will experience severe adverse health effects.

# %%
from IPython.display import display,HTML
display(HTML('''<img src="https://www.orfonline.org/wp-content/uploads/2019/07/Map-0022.jpg">'''))
# Out:
# <img src="https://www.orfonline.org/wp-content/uploads/2019/07/Map-0022.jpg">

# %% [markdown]
# # IMPORTING NECESSARY LIBRARIES FOR DATA VISUALIZATION

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # IMPORTING DATASET FOR VISUALIZATION

# %%
data = pd.read_csv('city_day.csv')
print(data)
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %% [markdown]
# # CHECKING TOP 10

# %%
data.head(10)
# Out:
#         City        Date  PM2.5  PM10      NO    NO2     NOx  NH3      CO  \
# 0  Ahmedabad  2015-01-01    NaN   NaN    0.92  18.22   17.15  NaN    0.92
# 1  Ahmedabad  2015-01-02    NaN   NaN    0.97  15.69   16.46  NaN    0.97
# 2  Ahmedabad  2015-01-03    NaN   NaN   17.40  19.30   29.70  NaN   17.40
# 3  Ahmedabad  2015-01-04    NaN   NaN    1.70  18.48   17.97  NaN    1.70
# 4  Ahmedabad  2015-01-05    NaN   NaN   22.10  21.42   37.76  NaN   22.10
# 5  Ahmedabad  2015-01-06    NaN   NaN   45.41  38.48   81.50  NaN   45.41
# 6  Ahmedabad  2015-01-07    NaN   NaN  112.16  40.62  130.77  NaN  112.16
# 7  Ahmedabad  2015-01-08    NaN   NaN   80.87  36.74   96.75  NaN   80.87
# 8  Ahmedabad  2015-01-09    NaN   NaN   29.16  31.00   48.00  NaN   29.16
# 9  Ahmedabad  2015-01-10    NaN   NaN     NaN   7.04    0.00  NaN     NaN
#
#      SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  27.64  133.36     0.00     0.02    0.00  NaN        NaN
# ...

# %% [markdown]
# # TOP 10 CITY WITH HIGHEST AQI

# %%
data1 = data['AQI'].dropna()
top_10_city = data_day.loc[data1.index].groupby('City')['AQI'].mean().reset_index()
top_10_city.sort_values('AQI', ascending=False, inplace=True)
top_10_city.head(10)
# Out:
#             City         AQI
# 0      Ahmedabad  452.122939
# 10         Delhi  259.487744
# 21         Patna  240.782042
# 12      Gurugram  225.123882
# 19       Lucknow  217.973059
# 23       Talcher  172.886819
# 16    Jorapokhar  159.251621
# 6   Brajrajnagar  150.280505
# 18       Kolkata  140.566313
# 13      Guwahati  140.111111

# %% [markdown]
# # 5 DAY ANALYSIS OF PARTICULAR CITY

# %%
print("--------------------Dataset for Air Quality in India------------------------")
print("\n")
print("\t\t---------Data of City Day---------")
print("\n")
print(data.head())
# Out:
# --------------------Dataset for Air Quality in India------------------------
#
#
# 		---------Data of City Day---------
#
#
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %% [markdown]
# # DESCRIBING OUR DATASET

# %%
print("--------------------Information of Dataset for Air Quality in India------------------------")
print("\n")
print("\t\t---------Info of City Day Data---------")
print("\n")
print(data.info())
# Out:
# --------------------Information of Dataset for Air Quality in India------------------------
#
#
# 		---------Info of City Day Data---------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
# ...

# %% [markdown]
# # TOTAL NUMBER OF CITIES

# %%
cities = data['City'].value_counts()
print(f'Total number of cities in the dataset : {len(cities)}')
print(cities.index)
# Out:
# Total number of cities in the dataset : 26
# Index(['Lucknow', 'Delhi', 'Bengaluru', 'Chennai', 'Mumbai', 'Ahmedabad',
#        'Hyderabad', 'Patna', 'Gurugram', 'Visakhapatnam', 'Amritsar',
#        'Jorapokhar', 'Jaipur', 'Thiruvananthapuram', 'Amaravati',
#        'Brajrajnagar', 'Talcher', 'Kolkata', 'Guwahati', 'Coimbatore',
#        'Shillong', 'Chandigarh', 'Bhopal', 'Kochi', 'Ernakulam', 'Aizawl'],
#       dtype='object')

# %% [markdown]
# # GRAPHICAL REPRESENTATION OF DIFFERENT GASES WITH PM

# %%
data.hist(figsize=(16, 10))
plt.show()

# %% [markdown]
# # PIE CHART REPRESENTATION OF AQI OF DIFFERENT CITIES

# %%
aqi = data.groupby('City')['AQI'].min().reset_index()
aqi  = aqi.sort_values("AQI")
aqi = aqi.head(10)
fig1, ax1 = plt.subplots(figsize=(15,10))
ax1.pie(aqi['AQI'].tolist(), labels=aqi['City'].tolist(), autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.legend(loc='right',bbox_to_anchor=(1.2,0.9))
plt.show()

# %% [markdown]
# # DELHI 5 YEARS AQI ANALYSIS

# %%
data['Date']=pd.to_datetime(data['Date'])
data['day_name']=data['Date'].dt.day_name()
data['Month'] = data['Date'].dt.strftime('%m-%d')
cdict = {'Good':'green',  'Satisfactory': 'aqua', 'Moderate': 'yellow',  
         'Poor':'maroon',   'Very Poor':'red' ,    'Severe': 'black' }
week_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
def colour(data,cdict):
    return [cdict[x] for x in data.index]
city_data = data[data['City'] == 'Delhi']
for i in sorted(set(data['Date'].dt.year)):
    city_date = pd.DataFrame(city_data['AQI_Bucket'][city_data['Date'].dt.year == i ].value_counts())
    city_date.plot(kind='pie',x='index',y='AQI_Bucket',title='Delhi AQI Year- ' + str(i),colors=colour(city_date,cdict),legend=False,figsize=(5,5))

# %% [markdown]
# # MARCH-APRIL THREE YEARS ANALYSIS

# %%
def past_years(city):
    last_3yr = [2018,2019,2020]
    city_data = data[data['City'] == city]
    plt.figure(figsize=(16,6))
    for i in last_3yr:
        time = city_data[['Month','AQI']][(city_data['Date'].dt.year == i) & (city_data['Month'].between('03-23','04-15'))].set_index('Month')
        plt.plot(time,linewidth=3, markersize=12,marker='o')
        plt.xlabel('23 Mar - 15 Apr')
        plt.ylabel('AQI Level (<100 is Satisfactory)')
        plt.title(city + ' Air - Quality through Years')
        plt.legend(last_3yr)
past_years('Delhi')

# %% [markdown]
# # LEVEL OF POLLUTION

# %%
city_15_20 = pd.DataFrame(city_data['AQI_Bucket'].value_counts())
city_15_20.plot(kind='barh',y='AQI_Bucket',color=colour(city_15_20,cdict),legend=False,title='Level of Pollution (2015-2020) in Days')
plt.xlabel('Count(Days)',fontsize=14)
# Out:
# Text(0.5, 0, 'Count(Days)')

# %% [markdown]
# # 5 DAYS DIFFERENT CITIES CO LEVEL

# %%
df_chart =data.pivot(index='Date', columns='City', values='CO')
df_chart = df_chart.fillna(df_chart.mean())
df_chart.head()
# Out:
# City        Ahmedabad    Aizawl  Amaravati  Amritsar  Bengaluru    Bhopal  \
# Date
# 2015-01-01       0.92  0.283628   0.627904  0.551301       0.33  0.880393
# 2015-01-02       0.97  0.283628   0.627904  0.551301       1.35  0.880393
# 2015-01-03      17.40  0.283628   0.627904  0.551301      17.40  0.880393
# 2015-01-04       1.70  0.283628   0.627904  0.551301       5.05  0.880393
# 2015-01-05      22.10  0.283628   0.627904  0.551301       1.83  0.880393
#
# City        Brajrajnagar  Chandigarh  Chennai  Coimbatore  ...  Jorapokhar  \
# Date                                                       ...
# 2015-01-01      1.798274    0.631349     1.17    0.949321  ...    0.663049
# 2015-01-02      1.798274    0.631349     1.23    0.949321  ...    0.663049
# 2015-01-03      1.798274    0.631349     0.77    0.949321  ...    0.663049
# 2015-01-04      1.798274    0.631349     1.00    0.949321  ...    0.663049
# 2015-01-05      1.798274    0.631349     0.90    0.949321  ...    0.663049
#
# ...
